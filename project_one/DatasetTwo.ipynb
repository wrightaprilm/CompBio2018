# %% [markdown]
# # Data Project One
#
# Below are the questions for the first data practical assignment. This project uses the "FossilAnts.csv" file, located in the data directory for the project. The point value of each question is denoted next to it. A blank cell is below each for your answer; feel free to create more blank cells as needed.

# %% [markdown]
# 1. 5 pts. Import the pandas library and load the data. The data for this part of the practical is located in the data directory. Save the data in a variable called project_dat. Print the data to the screen to ensure it loaded correctly.

# %%
import pandas as pd
project_dat = pd.read_csv("../data/FossilAnts.csv")
project_dat
# Out:
#                            taxon reference_no  \
# 0        Agroecomyrmex_duisburgi        44414
# 1          Eulithomyrmex_rugosus         4971
# 2         Eulithomyrmex_striatus         4971
# 3                  Amblyoponinae        59088
# 4                   Amblyoponini        53165
# 5              Casaleia_eocenica        43781
# 6               Casaleia_inversa        41286
# 7          Casaleia_longiventris        37344
# 8            Casaleia_orientalis        56094
# 9             Myopopone_sinensis        16579
# 10         Stigmatomma_electrina        44602
# 11           Stigmatomma_groehni        44602
# 12         Aneuretellus_deformis        44404
# 13        Britaneuretus_anglicus        37729
# 14              Burmomyrma_rossi        39313
# 15     Cananeuretus_occidentalis        36535
# 16                   Mianeuretus        44418
# 17         Mianeuretus_eocenicus        44418
# 18         Mianeuretus_mirabilis         4971
# 19      Paraneuretus_dubovikoffi        56094
# 20      Paraneuretus_longicornis        40999
# 21       Paraneuretus_tornquisti        40999
# 22        Pityomyrmex_tornquisti        40999
# 23       Protaneuretus_succineus        40999
# 24       Archaeopone_kzylzharica        37059
# 25           Archaeopone_taylori        35238
# 26                       Armania        39728
# 27              Armania_capitata        39728
# 28               Armania_curiosa        35238
# 29              Armania_pristina        39728
# ..                           ...          ...
# 759        Gerontoformica_magnus        50661
# 760     Gerontoformica_maraudera        58266
# 761  Gerontoformica_occidentalis        44281
# 762    Gerontoformica_orientalis        36535
# 763       Gerontoformica_pilosus        50661
# 764      Gerontoformica_robustus        50661
# 765       Gerontoformica_rugosus        50661
# 766      Gerontoformica_spiralis        50661
# 767     Gerontoformica_subcuspis        50661
# 768        Gerontoformica_tendir        50661
# 769         Haidomyrmex_cerberus        39313
# 770       Haidomyrmex_scimitarus        44280
# 771          Haidomyrmex_zigrasi        44280
# 772      Haidomyrmodes_mammuthus        44281
# 773         Haidoterminus_cippus        47973
# 774                  Sphecomyrma        36535
# 775       Sphecomyrma_canadensis        38990
# 776            Sphecomyrma_freyi        36535
# 777           Sphecomyrma_mesaki        36535
# 778           Zigrasimecia_ferox        50003
# 779         Zigrasimecia_tonsora        47310
# 780                     Baikuris        48703
# 781               Baikuris_casei         5815
# 782        Baikuris_mandibularis        39885
# 783             Baikuris_maximus        53728
# 784           Baikuris_mirabilis        39885
# 785    Ceratomyrmex_ellenbergeri        59331
# 786          Cretomyrma_arnoldii        37059
# 787         Cretomyrma_unicornis        37059
# 788      Dlusskyidris_zherichini        37059
#
#                             subfamily&Tribe           Genus Fossil  min_ma  \
# 0                    Agroecomyrmecinae;None   Agroecomyrmex    Yes    33.9
# 1                    Agroecomyrmecinae;None   Eulithomyrmex    Yes    33.9
# 2                    Agroecomyrmecinae;None   Eulithomyrmex    Yes    33.9
# 3                   Amblyoponinae;None;None             Yes  20.44   23.03
# 4    Amblyoponinae;AmblyoponiniAmblyoponini             Yes  20.44   23.03
# 5                        Amblyoponinae;None        Casaleia    Yes    40.4
# 6                        Amblyoponinae;None        Casaleia    Yes   5.333
# 7                        Amblyoponinae;None        Casaleia    Yes  11.608
# 8                        Amblyoponinae;None        Casaleia    Yes    33.9
# 9                        Ambyloponinae;None       Myopopone    Yes  11.608
# 10                       Ambyloponinae;None     Stigmatomma    Yes    33.9
# 11                       Ambyloponinae;None     Stigmatomma    Yes    33.9
# 12                         Aneuretinae;None    Aneuretellus    Yes    41.3
# 13                         Aneuretinae;None   Britaneuretus    Yes    33.9
# 14                         Aneuretinae;None      Burmomyrma    Yes    93.5
# 15                         Aneuretinae;None    Cananeuretus    Yes    70.6
# 16                         Aneuretinae;None     Mianeuretus    Yes    46.2
# 17                         Aneuretinae;None     Mianeuretus    Yes    46.2
# 18                         Aneuretinae;None     Mianeuretus    Yes    33.9
# 19                         Aneuretinae;None    Paraneuretus    Yes    33.9
# 20                         Aneuretinae;None    Paraneuretus    Yes    33.9
# 21                         Aneuretinae;None    Paraneuretus    Yes    33.9
# 22                         Aneuretinae;None     Pityomyrmex    Yes    33.9
# 23                         Aneuretinae;None   Protaneuretus    Yes    33.9
# 24                          Armaniinae;None     Archaeopone    Yes    89.8
# 25                          Armaniinae;None     Archaeopone    Yes    70.6
# 26                          Armaniinae;None         Armania    Yes    89.8
# 27                          Armaniinae;None         Armania    Yes    89.8
# 28                          Armaniinae;None         Armania    Yes    70.6
# 29                          Armaniinae;None         Armania    Yes    89.8
# ..                                      ...             ...    ...     ...
# 759                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 760                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 761                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 762                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 763                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 764                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 765                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 766                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 767                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 768                      Sphecomyrinae;None  Gerontoformica    Yes    93.5
# 769                      Sphecomyrinae;None     Haidomyrmex    Yes    93.5
# 770                      Sphecomyrinae;None     Haidomyrmex    Yes    93.5
# 771                      Sphecomyrinae;None     Haidomyrmex    Yes    93.5
# 772                      Sphecomyrinae;None   Haidomyrmodes    Yes    99.6
# 773                      Sphecomyrinae;None   Haidoterminus    Yes    70.6
# 774                        Sphecomyrma;None     Sphecomyrma    Yes    89.8
# 775                        Sphecomyrma;None     Sphecomyrma    Yes    70.6
# 776                        Sphecomyrma;None     Sphecomyrma    Yes    89.8
# 777                        Sphecomyrma;None     Sphecomyrma    Yes    89.8
# 778                        Sphecomyrma;None    Zigrasimecia    Yes    93.5
# 779                        Sphecomyrma;None    Zigrasimecia    Yes    93.5
# 780                     Sphecomyrminae;None        Baikuris    Yes    72.1
# 781                     Sphecomyrminae;None        Baikuris    Yes    89.8
# 782                     Sphecomyrminae;None        Baikuris    Yes    83.6
# 783                     Sphecomyrminae;None        Baikuris    Yes    99.6
# 784                     Sphecomyrminae;None        Baikuris    Yes    83.6
# 785                     Sphecomyrminae;None    Ceratomyrmex    Yes    93.5
# 786                     Sphecomyrminae;None      Cretomyrma    Yes    83.6
# 787                     Sphecomyrminae;None      Cretomyrma    Yes    83.6
# 788                     Sphecomyrminae;None    Dlusskyidris    Yes    83.6
#
#     max_ma     Notes
# 0       38      Note
# 1     37.2      Note
# 2     37.2      Note
# 3     Note       NaN
# 4     Note       NaN
# 5     48.6      Note
# 6    15.97      Note
# 7     12.7      Note
# 8       38      Note
# 9    15.97      Note
# 10      38      Note
# 11      38      Note
# 12    47.8      Note
# 13      38      Note
# 14    99.6      Note
# 15    83.5      Note
# 16    50.3      Note
# 17    50.3      Note
# 18    37.2      Note
# 19      38      Note
# 20      38      Note
# 21      38      Note
# 22      38      Note
# 23      38      Note
# 24       0      Note
# 25    83.5      Note
# 26       0      Note
# 27       0      Note
# 28    83.5      Note
# 29       0      Note
# ..     ...       ...
# 759   99.6      Note
# 760   99.6      Note
# 761   99.6      Note
# 762   99.6      Note
# 763   99.6      Note
# 764   99.6      Note
# 765   99.6      Note
# 766   99.6      Note
# 767   99.6      Note
# 768   99.6      Note
# 769   99.6      Note
# 770   99.6      Note
# 771   99.6      Note
# 772  105.3      Note
# 773   83.5      Note
# 774      0      Note
# 775   83.5      Note
# 776      0      Note
# 777      0      Note
# 778   99.6      Note
# 779   99.6      Note
# 780   83.6      Note
# 781      0      Note
# 782   89.8      Note
# 783  105.3      Note
# 784   89.8      Note
# 785   99.6  Stem Ant
# 786   86.3  Stem Ant
# 787   86.3  Stem Ant
# 788   86.3      Note
#
# [789 rows x 8 columns]

# %% [markdown]
# 2. (2pts) Check the datatypes of each column. There is a column called reference number. This is a static identifier - it should not be changed, and is an indexer used to identify this specimen uniquely. Do we want to treat it as an integer (this is an opinion question - answers may vary).

# %%
project_dat.dtypes
# Out:
# taxon            object
# reference_no      int64
# subfamily        object
# Tribe            object
# Genus            object
# Fossil           object
# min_ma          float64
# max_ma          float64
# Notes            object
# dtype: object

# %% [markdown]
# 3. (3 pts) Change the datatype of the reference number column to object.

# %% [markdown]
# 4. (5 pts) Look at your data spreadsheet in a spreadsheet viewer. What are the missing data values? In particular, have a look at the min_ma and max_ma columns. In your opinion, are these intelligent missing values for the dataset? Why or why not? If not, how would you like to change them?  The below cell is a markdown cell, meaning it will hold text input.

# %% [markdown]
# 5. (5pts) Now do it - replace your missing values with these more logical missing values. Hint: look at the replace() method.

# %% [markdown]
# 6. (5 points) Are there any columns in your dataset that contain two pieces of data? If so, identify them.

# %% [markdown]
# 7. (5pts) Now split these columns into two separate columns.

# %% [markdown]
# Next, we will test a hypthesis. Your hypthesis is that there are more specimens in the 75 million years ago (mya) - 100 mya interval than the 30 mya to the present interval.
#
# 8. (5 pts) Write out the steps you would take to address this question. Will you need to split up the data? Will you need to group the data based on the values in some column?

# %% [markdown]
# 9. (10 pts) Perform the operations you described in (8).

# %% [markdown]
# 10. (5 pts) Do the results of your code support the hypothesis?

# %% [markdown]
# 11. (5 pts) Save the dataframe with the split columns into the data directory. Save it as a csv file called "column_separated.csv"

# %% [markdown]
# 12. (10 pts) Write a function that does the column splitting and the row counting based on your hypothesis. It should take three arguments, a dataframe, and the start and end point of the intervals. It should write out one dataframe.

# %% [markdown]
# 13. (5 pts) Run the function on the ant fossil dataset. Save the output to a CSV file, in the data directory, called "function_output.csv", and open both CSV files. Do they look the same? (They should - this step is more to get you to think about checking your output. I'm simply going to look at the file and make sure you did it).

# %% [markdown]
# 14. (15 pts) Next, move the function to a script. The output from your script should be a CSV file, with the column splitting operation performed. How would you like to return the results of the counting operation from your code? (this last bit is a genuine matter of opinion). Make sure you have your script anatomy correct! For this part, do not worry about passing in the input and output datafiles, simply hard code them in. Save the script in the scripts directory as "question_14.py"

# %% [markdown]
# 15. (5 pts) Now, we're going to think about passing in the input and output data files. Make a copy of your script and title it "question_16.py". Would you rather use argparse or sys to pass in the name of the input file and output file? This is an opinion question.

# %% [markdown]
# 16. (10 pts) Set up the input and output argument passing you described above.

# %% [markdown]
# Bonus: (2 pts). What is one thing you feel like you get really well? What is one thing you don't?
