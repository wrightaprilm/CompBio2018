# %% [markdown]
# # Data Project One
#
# Below are the questions for the first data practical assignment. This project is for the Piller students.
# The point value of each question is denoted next to it. A blank cell is below each for your answer; feel free to create more blank cells as needed.

# %% [markdown]
# 1. 10 pts. I do not want to make your data available to the whole class, so follow these instructions to upload your data. First, in the graphical interface, navigate to the data directory. Click the 'Upload' button.
#
# ![upload](img/UploadButton.png)
#
# Choose your data file to upload.
#
# Import the pandas library and load the data. You will use `read_excel`, rather than `read_csv`, for obvious reasons. You may want to look at the `header` argument - are your column names in row 0 or row 1? Save the data in a variable called project_dat. Print the data to the screen to ensure it loaded correctly.

# %%
import pandas as pd
df = pd.read_excel("../data/messy_data_set.xlsx", skiprows=0, header=1)

# %% [markdown]
# 2. (5pts) Check the datatypes of each column. Use a comment to note if there are any that surprise you. (Hint: look at the data type (float, int), and the precision of the numbers in the columns). In the comments, also note what steps you would have to take before you could change the datatype in the columns to comething more sensical (hint: think about missing data).

# %%
df = df[0:29]

# %% [markdown]
# 3. (5 pts) Look at your data spreadsheet in a spreadsheet viewer. What are the missing data values. In your opinion, are these intelligent missing values for the dataset? Why or why not? If not, how would you like to change them?  The below cell is a markdown cell, meaning it will hold text input.

# %%
df
# Out:
#        Specimen Standard length Predorsal length preanal length  \
# 0             1           82.53            38.62          56.54
# 1    Paratype 2         7.988cm            38.28          53.61
# 2             3           76.34             36.3          50.56
# 3             4           71.87            33.02       4.824 cm
# 4             7           62.05            29.79          41.45
# 5             8        6.051 cm            27.89          38.19
# 6             9           59.33             28.4          38.77
# 7   Holotype 11           57.05            28.08          38.54
# 8            12           56.88            27.14          37.79
# 9   Paratype 13           57.49            27.99           37.7
# 10           14         no data            26.43       3.673 cm
# 11           15           52.76            26.11          34.92
# 12           18            53.7            25.55          35.05
# 13           19        5.207 cm            25.41          33.32
# 14  Paratype 20           54.35            26.29          35.36
# 15           21           53.84            24.94          34.68
# 16           22           52.97        2.439 cm           33.89
# 17           23           51.84            25.13          33.74
# 18  Paratype 24           54.79            25.25          35.06
# 19           25            48.3            24.05          31.12
# 20           26           48.94            23.62          32.32
# 21           27        5.047 cm            23.98           33.1
# 22  Paratype 28           46.62            22.93          30.34
# 23  Paratype 29           49.53            24.53          31.87
# 24           30           47.56            22.91          30.55
# 25           31           45.17            22.03        no data
# 26           32            46.5            22.49           29.9
# 27           33           46.87            22.32          30.23
# 28           34           41.08            20.08          27.08
#
#    prepelvic length prepectoral length dorsal-fin base length  \
# 0             40.41              19.59                  10.33
# 1              38.3                 18                   9.18
# 2             36.98              17.89                   8.92
# 3             33.76              17.19                   8.97
# 4             29.56              14.23                   6.65
# 5             29.17              14.98                   7.85
# 6             29.06              13.68                   6.79
# 7             29.03              13.49                no data
# 8             28.22              13.44                   6.27
# 9             28.91              13.06                   7.01
# 10            27.42              13.48                   6.32
# 11            26.46              13.08                   6.12
# 12             26.8              13.48                   6.13
# 13            25.07              13.09                   6.24
# 14            26.61            no data                   6.14
# 15            26.24              12.56                   6.64
# 16            25.91              13.47                   6.55
# 17            25.73              13.09                    6.3
# 18            26.51              12.46                   6.74
# 19             24.3              11.56                   6.04
# 20            24.15              11.16                   5.94
# 21            25.23              12.23                   5.76
# 22            23.08              10.93                   5.87
# 23            25.38               11.4                   5.59
# 24            23.69              11.12                   5.74
# 25            22.74              10.96                   5.15
# 26            23.15              10.95                   5.34
# 27            23.62            1.064cm                   5.22
# 28            20.87               9.85                   4.68
#
#    dorsal fin origin to pectoral origin dorsal fin origin to pelvic origin  \
# 0                                  27.3                              22.47
# 1                                 26.84                               22.8
# 2                                 25.66                              21.16
# 3                                 23.27                              19.86
# 4                                 19.75                              16.75
# 5                                 19.18                              15.94
# 6                                 19.28                              15.67
# 7                                 19.05                                 16
# 8                                 18.87                               15.2
# 9                                 18.65                           1.595 cm
# 10                                18.13                              14.84
# 11                                17.26                              14.46
# 12                             1.652 cm                              13.73
# 13                                 15.8                              13.35
# 14                                18.18                              14.78
# 15                                17.44                              14.16
# 16                                16.81                              14.28
# 17                                16.76                              14.01
# 18                                16.97                              14.35
# 19                                15.72                           1.273 cm
# 20                                15.51                              13.25
# 21                                16.35                              1.327
# 22                                14.64                              12.35
# 23                                 15.8                              13.24
# 24                                15.34                              12.56
# 25                              no data                              11.85
# 26                                15.11                              12.51
# 27                                15.55                              12.65
# 28                                13.58                              10.95
#
#    dorsal terminus to anal origin                 ...                  \
# 0                           19.34                 ...
# 1                           19.16                 ...
# 2                           18.22                 ...
# 3                           17.65                 ...
# 4                           14.98                 ...
# 5                           14.64                 ...
# 6                           13.93                 ...
# 7                           13.37                 ...
# 8                           13.63                 ...
# 9                           14.09                 ...
# 10                          13.36                 ...
# 11                          12.87                 ...
# 12                          13.08                 ...
# 13                          12.14                 ...
# 14                          13.28                 ...
# 15                          13.17                 ...
# 16                          13.23                 ...
# 17                          12.79                 ...
# 18                          12.98                 ...
# 19                          11.19                 ...
# 20                          11.64                 ...
# 21                          11.89                 ...
# 22                          11.24                 ...
# 23                          11.79                 ...
# 24                          11.17                 ...
# 25                          10.58                 ...
# 26                          10.81                 ...
# 27                          11.27                 ...
# 28                           9.37                 ...
#
#    pectoral origin to pelvic origin anal-fin base length  \
# 0                             21.15                19.39
# 1                             19.84                19.29
# 2                           no data                1.891
# 3                             16.35                17.11
# 4                             14.55                14.81
# 5                             13.81                14.93
# 6                             14.65                14.86
# 7                             14.04                13.66
# 8                             13.42                13.88
# 9                             14.19                13.95
# 10                            12.87                13.37
# 11                            12.17                12.72
# 12                            12.13                12.83
# 13                          1.221cm                13.25
# 14                            12.99                13.09
# 15                            13.12                12.08
# 16                            13.25                12.88
# 17                            12.53                12.41
# 18                            12.45                13.13
# 19                            11.59                11.61
# 20                            11.74                11.36
# 21                            11.98                12.03
# 22                            11.26                11.38
# 23                            12.32                11.71
# 24                             11.5                10.95
# 25                            11.27                10.84
# 26                            11.03                10.97
# 27                            10.89                10.57
# 28                             9.87                  9.9
#
#    anal origin to adipse origin length of caudal peduncle  \
# 0                         22.62                      7.71
# 1                         21.65                      7.11
# 2                         21.05                      6.91
# 3                         20.39                      6.45
# 4                         17.03                      5.61
# 5                         17.21                      5.58
# 6                         16.59                      5.09
# 7                      1.543 cm                      5.55
# 8                         15.98                      5.62
# 9                         15.78                      5.62
# 10                        15.17                       4.9
# 11                        14.09                      5.17
# 12                        14.46                      4.74
# 13                        14.76                      4.76
# 14                        15.27                      4.99
# 15                        14.93                      5.11
# 16                        15.12                      5.12
# 17                        14.89                      5.07
# 18                        14.69                      5.37
# 19                        13.29                      4.39
# 20                        13.59                      4.17
# 21                        13.78                       4.4
# 22                        12.41                      3.97
# 23                        13.81                      4.32
# 24                        12.66                      4.22
# 25                        12.02                      4.13
# 26                        12.37                      3.92
# 27                          NaN                      4.07
# 28                        11.35                      3.45
#
#    Adipose origin to base of last anal fin ray Maxillary length snout length  \
# 0                                          9.4             8.19          5.4
# 1                                         9.16             8.05         5.03
# 2                                         8.77             7.64         4.82
# 3                                         8.27             7.01      no data
# 4                                          7.1             6.34         3.98
# 5                                         6.87             6.39         4.15
# 6                                         6.56             6.22         3.01
# 7                                         6.45             6.13         4.37
# 8                                         6.54             5.99         3.95
# 9                                         6.23             5.94          3.8
# 10                                        5.84             5.46         3.13
# 11                                        5.82             5.11         2.89
# 12                                        5.22             5.33         3.38
# 13                                        5.56             5.67         3.43
# 14                                        6.03          no data         3.19
# 15                                           6             5.31         3.42
# 16                                        5.95             4.99         3.08
# 17                                        5.51             4.85         3.01
# 18                                        6.17             5.32         3.25
# 19                                        5.34             4.68         2.97
# 20                                        5.27             4.48         3.42
# 21                                        5.73             4.73         3.41
# 22                                        5.24             4.43         2.53
# 23                                        5.75             4.87         3.34
# 24                                        5.42             4.66         3.09
# 25                                        5.33             4.38         2.96
# 26                                        5.12             4.32         2.85
# 27                                         NaN              4.2         2.97
# 28                                        4.52             3.65         2.33
#
#    vertical orbit diameter head length anterior margin of orbit to maxilla
# 0                     7.68       20.93                                3.07
# 1                     7.34       19.68                                2.74
# 2                     6.55        18.5                                2.54
# 3                     6.16       1.773                                2.09
# 4                     5.63       16.86                                2.08
# 5                     5.53       15.16                                2.21
# 6                     5.88       14.96                                2.13
# 7                     5.21       14.33                                2.16
# 8                     5.34       14.31                                2.23
# 9                     5.62       14.34                                2.05
# 10                    5.15       13.84                                1.96
# 11                    5.55    1.361 cm                                1.88
# 12                    5.02       13.69                                1.97
# 13                    4.87       13.51                                2.05
# 14                    5.42          14                                2.02
# 15                    5.07        13.4                                2.14
# 16                    5.28       13.11                                1.99
# 17                    5.18       13.32                                2.03
# 18                    4.99       13.46                                1.88
# 19                    4.64       12.42                                1.91
# 20                    4.83       12.75                                1.81
# 21                    5.17       12.83                                1.95
# 22                    4.75       12.32                                1.79
# 23                    4.94       12.68                                1.85
# 24                    4.65       12.38                                1.82
# 25                    4.37       11.56                                1.74
# 26                    4.82       11.86                                1.78
# 27                     4.6       12.16                                1.79
# 28                    4.21       10.78                                1.62
#
# [29 rows x 23 columns]

# %% [markdown]
# 4. (5 pts) Subset the data: let's make a new dataframe that contains only the rows that are specimens. That is, get rid of the rows that are summary stats or other measures. Call it subset_df

# %% [markdown]
# 5. (5 pts) Next, let's replace those cm and no data values. In plain language, what do we need to do to replace the cm and no data measurements?

# %% [markdown]
# 6. (10 pts) Perform the operations you described in (8).

# %% [markdown]
# 7. (5 pts) For the surprising datatypes in columns in question 2, you should now be able to change the columns that should be numeric to numeric types (int or float). Do that.

# %% [markdown]
# 8. (5 points) Are there any columns in your dataset that contain two pieces of data? If so, identify them.

# %% [markdown]
# 9. (5pts) Split the 'specimen' column into two columns - one that is the specimen number, and one that is whether the specimen is a holotype, a paratype or neither (just use missing data for this).

# %%
df['Specimen']
# Out:
# 0               1
# 1      Paratype 2
# 2               3
# 3               4
# 4               7
# 5               8
# 6               9
# 7     Holotype 11
# 8              12
# 9     Paratype 13
# 10             14
# 11             15
# 12             18
# 13             19
# 14    Paratype 20
# 15             21
# 16             22
# 17             23
# 18    Paratype 24
# 19             25
# 20             26
# 21             27
# 22    Paratype 28
# 23    Paratype 29
# 24             30
# 25             31
# 26             32
# 27             33
# 28             34
# Name: Specimen, dtype: object

# %% [markdown]
# 10. (5 pts) Group the data based on if a specimen is a holo, para or neither type. How many of each are there?

# %% [markdown]
# 11. (5 pts) Save the dataframe with the split columns into the data directory. Save it as a csv file called "column_separated.csv"

# %% [markdown]
# 12. (10 pts) Write a function that does the column splitting, the grouping, and the count. It should take one argument, the subset_df, as input.

# %% [markdown]
# 14. (15 pts) Next, move the function to a script. The output from your script should be a CSV file, with the column splitting operation performed. How would you like to return the results of the grouping and counting operation from your code? (this last bit is a genuine matter of opinion). Make sure you have your script anatomy correct! For this part, do not worry about passing in the input and output datafiles, simply hard code them in. Save the script in the scripts directory as "question_14.py"

# %%
sublist = df.Specimen.str.split(' ', 0)

for item in sub_list:
    if type(item) == 'list':
        print(item)

# %% [markdown]
# 15. (5 pts) Now, we're going to think about passing in the input and output data files. Make a copy of your script and title it "question_16.py". Would you rather use argparse or sys to pass in the name of the input file and output file? This is an opinion question.

# %% [markdown]
# 16. (5 pts) Set up the input and output argument passing you described above.

# %% [markdown]
# Bonus: (2 pts). What is one thing you feel like you get really well? What is one thing you don't?

# %%
def piller_project(subset_df):
   sub_list = subset_df['Specimen'].str.split(' ', 2)
   for item in sub_list:
    print(type(item))
   para_list = []
   spec_list = []

   for item in sub_list:
    if len(item) > 1:
        para_list.append(item[0])
        spec_list.append(item[1])
    else:
        para_list.append("None")
        spec_list.append(item[0])

   spec_series = pd.Series(spec_list)
   para_series = pd.Series(para_list)

   spec_stack = pd.concat([subset_df, spec_series], axis=1)
   total_stack = pd.concat([spec_stack, para_series], axis=1)
   subset_cor = total_stack

   subset_cor = subset_cor.drop("Specimen", axis=1)
   subset_cor = subset_cor.drop("Unnamed: 0", axis=1)

   subset_cor.columns = ([        'Standard length',
                                 'Predorsal length',
                                   'preanal length',
                                 'prepelvic length',
                               'prepectoral length',
                           'dorsal-fin base length',
             'dorsal fin origin to pectoral origin',
               'dorsal fin origin to pelvic origin',
                   'dorsal terminus to anal origin',
                 'dorsal terminus to pelvic origin',
                  'dorsal origin to adipose origin',
                  'adipose origin to hypural plate',
                 'pectoral origin to pelvic origin',
                             'anal-fin base length',
                     'anal origin to adipse origin',
                        'length of caudal peduncle',
      'Adipose origin to base of last anal fin ray',
                                 'Maxillary length',
                                     'snout length',
                          'vertical orbit diameter',
                                      'head length',
              'anterior margin of orbit to maxilla',
                                  'Specimen number',
                                            'Type'])

   print(subset_cor.groupby('Type').size())
   return(subset_cor)

# %%
piller_project(df)
# Out:
# <class 'float'>
# <class 'list'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'list'>
# <class 'float'>
# <class 'list'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'list'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'list'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'list'>
# <class 'list'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-8274767befc5> in <module>()
# ----> 1 piller_project(df)
#
# <ipython-input-41-343c86134875> in piller_project(subset_df)
#       7
#       8    for item in sub_list:
# ----> 9     if len(item) > 1:
#      10         para_list.append(item[0])
#      11         spec_list.append(item[1])
#
# TypeError: object of type 'float' has no len()
